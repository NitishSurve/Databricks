# %%
print("Hello World!")

# %%
# %sql

Select "HELLO"

# %%
# %run ./Includes/Setup

# %%
print(full_name)

# %%
# %fs ls '/databricks-datasets'

# %%
files = dbutils.fs.ls('/databricks-datasets')
print(files)

# %%
display(files)
